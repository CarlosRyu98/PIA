# %% [markdown]
# # Ejercicios Matplotlib

# %% [markdown]
# Tras hacer tus propias pruebas con la teoría de Matplotlib, completa los siguientes ejercicios en orden:

# %%
# pip install matplotlib

# %% [markdown]
# ---
# ## Ejercicio 1

# %% [markdown]
# Al igual que con el resto de módulos (Pandas, NumPy), tendrás que importar las librerías necesarias para poder trabajar:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %% [markdown]
# ---
# ## Ejercicio 2

# %% [markdown]
# Muestra un gráfico de líneas con una única línea. Esta línea ha de partir del punto (0,0) y tiene que terminar en el punto (10,10) pasando por tantos puntos como quieras:

# %%
plt.plot([0,10],[0,10], label = "linea")
plt.show()

# %% [markdown]
# ---
# ## Ejercicio 3

# %% [markdown]
# Muestra un gráfico de líneas con tres líneas de distintos colores y grosores. Cada una de ellas representará los valores de las funciones trigonométricas seno, coseno y tangente entre los 0 y los 720 grados. Además, muestra un título y las etiquetas (labels):

# %%
# Usar las matematicas para obtener lso valores de senos cosenos tangentes
grados = np.arange(0.0, 720.0)
seno = np.sin(grados*np.pi/180)
coseno = np.cos(grados*np.pi/180)
tangente = np.tan(grados*np.pi/180)

# Seno
plt.plot(seno, label = "Seno", color = "blue")
# Coseno
plt.plot(coseno, label = "Coseno", color = "green")
# Tangente
plt.plot(tangente, label = "Tangente", color = "red")

plt.title("Funciones Trigonométricas")
plt.ylim([-1.5,1.5])
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()

# %% [markdown]
# ---
# ## Ejercicio 4

# %% [markdown]
# Muestra un gráfico de barras comparando dos conjuntos de datos elegidos por tí:

# %%
ax = [1,2,3,4,5,6]
ay = [5,7,6,1,8,5]
bx = [1,2,3,4,5,6]
by = [3,1,4,5,2,7]

plt.bar(ax, ay, label = "linea 1", color = "lightblue", width = 0.5)
plt.bar(bx, by, label = "linea 2", color = "lightgreen", width = 0.25)

plt.title("Gráfico de barras doble")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()

plt.show()

# %% [markdown]
# ---
# ## Ejercicio 5

# %% [markdown]
# Muestra un gráfico de barras comparando tres conjuntos de datos elegidos por tí:

# %%
ax = [1,2,3,4,5,6]
ay = [5,7,6,1,8,5]
bx = [1,2,3,4,5,6]
by = [3,1,4,5,2,7]
cx = [1,2,3,4,5,6]
cy = [2,4,2,5,3,5]

plt.bar(ax, ay, label = "linea 1", color = "lightblue", width = 0.75)
plt.bar(bx, by, label = "linea 2", color = "lightgreen", width = 0.5)
plt.bar(cx, cy, label = "linea 2", color = "lightcoral", width = 0.25)

plt.title("Gráfico de barras triple")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()

plt.show()

# %% [markdown]
# ---
# ## Ejercicio 6

# %% [markdown]
# Crea un conjunto de datos aleatorios con valores comprendidos entre el 0 y el 1000. Muestra el histograma con tramos de 100 en 100:

# %%
valores = np.random.randint(1000, size = 1000)
secciones = np.linspace(0, 100, 10)

plt.hist(valores, secciones, histtype = "bar", rwidth = 0.75)

plt.title("Histograma")
plt.xlabel("Tramos")
plt.ylabel("Valores/Tramo")
plt.show()

# %% [markdown]
# ---
# ## Ejercicio 7

# %% [markdown]
# Muestra en un gráfico de dispersión dos conjuntos de datos aleatorios generados por tí. Estos datos deben ser valores comprendidos entre el 0 y el 25, tanto en el eje X como en el eje Y. Cada conjunto se pintará de un color distinto:

# %%
# ax = [1,2,3,4,5,6]
# ay = [5,7,6,1,8,5]
# bx = [1,2,3,4,5,6]
# by = [3,1,4,5,2,7]
# cx = [1,2,3,4,5,6]
# cy = [2,4,2,5,3,5]

ax = np.random.randint(25, size = [10])
ay = np.random.randint(25, size = [10])
bx = np.random.randint(25, size = [10])
by = np.random.randint(25, size = [10])
cx = np.random.randint(25, size = [10])
cy = np.random.randint(25, size = [10])

plt.scatter(ax, ay, label = "Datos 1", color = "lightblue")
plt.scatter(bx, by, label = "Datos 2", color = "lightgreen")
plt.scatter(cx, cy, label = "Datos 3", color = "lightcoral")


plt.title("Gráfico de dispersión")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()

plt.show()

# %% [markdown]
# ---
# ## Ejercicio 8

# %% [markdown]
# Muestra un gráfico circular estilizado con la distribución de tus horas del día:

# %%
datos = [8, 4, 1, 1, 1, 2, 7]
actividades = ["Dormir", "Clase", "Karate", "Comida", "Transporte", "Teatro", "Ocio"]
colores = ["blue", "green", "brown", "gray", "gray", "purple", "red"]
explosion = [.10,.10,.10,0,0,.10,.10]

plt.pie(datos, labels = actividades, colors = colores, startangle = 90,
        shadow = True, explode = explosion)

plt.title("Gráfico circular")
plt.show()

# %% [markdown]
# ---
# ## Ejercicio 9

# %% [markdown]
# Trata de cargar una imágen en blanco y negro en Python y mostrar el histograma con los valores de sus píxeles:

# %%
# imagen = Image.open("03_Matplotlib_Imagen.jpg")
# gImagen = imagen.convert('L')
# valores=np.asarray(gImagen)
# gImagen.save("03-ImagenGuardada.jpg")

valores = plt.imread("lenna.png")
print(valores.shape)
sections = np.linspace(0, 1, 6)

plt.hist(valores, sections, histtype = "bar", rwidth = 0.75)

plt.title("Histograma")
plt.xlabel("Tramos")
plt.ylabel("Valores/Tramo")
plt.show()
# Out:
# (512, 512)

# %% [markdown]
# ---
# ## Ejercicio 10

# %% [markdown]
# Hay una página web llamada [Kaggle](https://www.kaggle.com/datasets) donde se publican distintos datasets y trabajos de machine learning sobre los mismos. Descárgate un dataset de tu elección y muestra datos relevantes del mismo utilizando las gráficas vistas hasta ahora:

# %%
df = pd.read_csv("03-videogames.csv")

print(df.columns)
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df10 = df.head(5)


fig, a1 = plt.subplots()
a2 = a1.twinx()
w = .66
localBar = a2.bar(df10.Rank-w/2, df10.EU_Sales, label = "European Sales", width = w/3)
localBar = a2.bar(df10.Rank-w/6, df10.NA_Sales, label = "North American Sales", width = w/3)
localBar = a2.bar(df10.Rank+w/6, df10.JP_Sales, label = "Japanese Sales", width = w/3)
localBar = a2.bar(df10.Rank+w/2, df10.Other_Sales, label = "Other Sales", width = w/3)

globalBar = a1.bar(df10.Rank, df10.Global_Sales, label = "Global Sales", width = w*4/3, color = "purple")

plt.title("Sales Comparison")
a1.set_xlabel("Game")
a1.set_ylabel("Global Sales")
a2.set_ylabel("Local Sales")
a1.legend(loc = 9)
a2.legend(loc = 1)


# plt.bar(df10.Rank+.375, df10.Global_Sales, label = "Global Sales", width = .75, color = "purple")
# plt.bar(df10.Rank, df10.EU_Sales, label = "European Sales", width = 0.25)
# plt.bar(df10.Rank+.25, df10.NA_Sales, label = "North American Sales", width = 0.25)
# plt.bar(df10.Rank+.5, df10.JP_Sales, label = "Japanese Sales", width = 0.25)
# plt.bar(df10.Rank+.75, df10.Other_Sales, label = "Other Sales", width = 0.25)

# plt.title("Comparacion Sales")
# plt.xlabel("Juego")
# plt.ylabel("M. Ventas")
# plt.legend()

plt.show()

# %% [markdown]
# ---
# ## Ejercicio 11

# %% [markdown]
# Sobre el mismo dataset anterior u otro nuevo, muestra tres gráficas distintas a las aprendidas hasta el momento. Para ello puedes consultar la web de la [documentación de Matplotlib](https://matplotlib.org/stable/gallery/index.html):

# %%
# Varias piecharts juntas

df11a = df.head(20)

siglo = np.int64(df11a.Year/100)
decada = np.int64(df11a.Year/10)

siglos, countsiglos = np.unique(siglo*100, return_counts=1)
decadas, countdecadas = np.unique(decada*10, return_counts=1)

plt.pie(countsiglos, labels = siglos, labeldistance=.8, radius = 1, wedgeprops = dict(width=.2, edgecolor = "white"))
plt.pie(countdecadas, labels = decadas, labeldistance=.4, radius = .66, wedgeprops = dict(width=.66, edgecolor = "white"))

plt.title("Juegos por década y siglo")

plt.show()

# %%
# Barra Horizontal

df11b = df.head(5)

fig, a1 = plt.subplots()
a2 = a1.twiny()
w = .66
localBar = a2.barh(df11b.Rank, df11b.EU_Sales, label = "European Sales", height = w/3)
localBar = a2.barh(df11b.Rank, df11b.NA_Sales, label = "North American Sales", height = w/3)
localBar = a2.barh(df11b.Rank, df11b.JP_Sales, label = "Japanese Sales", height = w/3)
localBar = a2.barh(df11b.Rank, df11b.Other_Sales, label = "Other Sales", height = w/3)

globalBar = a1.barh(df11b.Rank, df11b.Global_Sales, label = "Global Sales", color = "purple", height = w/3*4)

plt.title("Sales Comparison")
a1.set_ylabel("Game (Rank)")
a1.set_xlabel("Global Sales")
a1.invert_yaxis()
a2.set_xlabel("Local Sales")
a1.legend(loc = 7)
a2.legend(loc = 4)

plt.show()

# %%
# Ejercicio10
