# %% [markdown]
# # UT3 - Práctica 1

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Antes de empezar a trabajar de verdad, tendrás que importar las librerías de NumPy y Matplotlib.Pyplot para poder trabajar con ellas:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Ejercicio 2

# %% [markdown]
# Importa la imagen "lenna_gris.png" utilizando la función de Pyplot "imread" y muéstrala por pantalla:

# %%
img = plt.imread("01_lenna_gris.png")

plt.imshow(img, cmap="gray")
plt.show()

# %% [markdown]
# ---
# ## Ejercicio 3

# %% [markdown]
# Investiga el tipo de datos utilizado en la variable donde has importado la imagen anteriormente. Muestra su tipo y contenido:

# %%
print(img.dtype)
print(img)
# Out:
# float32
# [[0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  [0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  [0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  ...
#  [0.16862746 0.16862746 0.19607843 ... 0.40784314 0.39215687 0.38431373]
#  [0.17254902 0.17254902 0.21568628 ... 0.40784314 0.4117647  0.42352942]
#  [0.17254902 0.17254902 0.21568628 ... 0.40784314 0.4117647  0.42352942]]

# %% [markdown]
# ---
# ## Ejercicio 4

# %% [markdown]
# Haz una copia de la imagen importada. Modifica las filas impares cambiando su valor a 0 y muéstrala por pantalla:

# %%
img2 = img.copy()
img2[1::2, :] = 0 # Empezando por el 1 coge los valores de 2 en 2 o algo así

print(img2)

plt.imshow(img, cmap="gray")
plt.show()
# Out:
# [[0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  [0.         0.         0.         ... 0.         0.         0.        ]
#  [0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  ...
#  [0.         0.         0.         ... 0.         0.         0.        ]
#  [0.17254902 0.17254902 0.21568628 ... 0.40784314 0.4117647  0.42352942]
#  [0.         0.         0.         ... 0.         0.         0.        ]]

# %% [markdown]
# ---
# ## Ejercicio 5

# %% [markdown]
# Crea una imagen de las mismas proporciones a la imagen importada pero con valores aleatorios decimales entre 0 y 1 y muéstrala por pantalla:

# %%
img3 = np.random.random(size=img.shape)
print(img3.shape)

plt.imshow(img3, cmap="gray")
plt.show()
# Out:
# (512, 512)

# %% [markdown]
# ---
# ## Ejercicio 6

# %% [markdown]
# Muestra el histograma de la imagen aleatoria generada:

# %%
plt.hist(img3, histtype="bar")

plt.show()

# %% [markdown]
# ---
# ## Ejercicio 7

# %% [markdown]
# Cambia la mitad izquierda de la imagen anterior por píxeles negros y muéstrala por pantalla:

# %%
img4 = img3.copy()
long = int(len(img4)/2)
img4[:, 0:long] = 0

plt.imshow(img4, cmap="gray")
plt.show()

# %% [markdown]
# ---
# ## Ejercicio 8

# %% [markdown]
# Muestra el histograma de la imagen del ejercicio 7:

# %%
plt.hist(img4, histtype="bar")

plt.show()

# %% [markdown]
# ---
# ## Ejercicio 9

# %% [markdown]
# Investiga cómo transformar una imagen de color a escala de grises sin utilizar ninguna librería. Define una función de obtenga una imagen a color como parametro y devuelva su versión en escala de grises:

# %%
def colorToGrayscale(img):
    grayimg = img.copy()
    grayimg = (0.299*grayimg[:,:,0] + 0.587*grayimg[:,:,1] + 0.114*grayimg[:,:,2])/255 # Función para pasar rgb a grayscale
    return grayimg

# %% [markdown]
# ---
# ## Ejercicio 10

# %% [markdown]
# Busca o edita dos imágenes distintas a color para que tengan el mismo tamaño. Importalas y conviertelas a escala de grises con la función que has programado previamente:

# %%
img10a = colorToGrayscale(plt.imread("01_panda1.jpg"))
img10b = colorToGrayscale(plt.imread("01_panda2.jpg"))

plt.imshow(img10a, cmap="gray")
plt.show()

plt.imshow(img10b, cmap="gray")
plt.show()

# %% [markdown]
# ---
# ## Ejercicio 11

# %% [markdown]
# Muestra las dos imágenes importadas en el ejercicio 10 (en escala de grises). Crea una tercera, siendo esta la suma de las dos anteriores, y muéstrala por pantalla:

# %%
plt.imshow(img10a, cmap="gray")
plt.show()

plt.imshow(img10b, cmap="gray")
plt.show()

img11 = img10a + img10b
plt.imshow(img11, cmap="gray")
plt.show()
