# %% [markdown]
# # UT4 - Práctica 1

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Antes de empezar a trabajar de verdad, tendrás que importar la librería de NumPy para poder trabajar con ella:

# %%
import numpy as np
import math

# %% [markdown]
# ---
# ## Ejercicio 2

# %% [markdown]
# Programa una clase "Neurona" que cuente con los siguientes elementos:
#
# *   Un constructor que reciba como parámetro el número de conexiones que tendrá de entrada la Neurona y un número entero del 1 al 4 que utilizaremos para definir la función de activación de la Neurona.
# Con el primer número, el constructor definirá un atributo "weights" o "pesos" de tipo array Numpy del tamaño recibido más uno (para el Bias).
# Todos los pesos deben ser inicializados con valores aleatorios entre 0 y 1 (el del Bias incluído)
#
# *   Una función "weighted_sum" o "suma_ponderada" que reciba como parámetro un array Numpy de la misma forma (shape) que el de los pesos de la Neurona.
# Este array contendrá los valores recibidos como entrada en la neurona (teniendo en cuenta que la primera posición siempre valdrá 1 ya que será el número por el que multipliquemos el peso del Bias).
# La función devolverá la suma ponderada de las entradas multiplicadas cada una por su peso
#
# *   Una función "step_function" o "funcion_activacion" que reciba como parámetro un array Numpy con los parámetros de entrada de la neurona.
# Desde esta función se utilizará la función de la suma ponderada y se aplicará la función de activación que corresponda según el parámetro recibido en el constructor:
#     1. Threshold o Escalonada
#     2. Sigmoid o Sigmoide
#     3. Hyperbolic_Tangent o Tangente_Hiperbolica
#     4. ReLU

# %%
class Neurona:
    def __init__(self, input1, input2):
        self.weights = np.random.random((1, input1+1))
        self.act = input2

    def weighted_sum(self, input):
        input = np.insert(input, 0, 1)
        suma = (self.weights*input).sum()
        return suma

    def step_function(self, input):
        suma = self.weighted_sum(input)
        if self.act == 1:
            print(self.sf_threshold(suma))
        elif self.act == 2:
            print(self.sf_sigmoid(suma))
        elif self.act == 3:
            print(self.sf_hyperbolic_tangent(suma))
        elif self.act == 4:
            print(self.sf_relu(suma))
        else:
            print("Ha habido un error.")

    def sf_threshold(self, suma):
        if suma <= 0: return 0
        else: return 1

    def sf_sigmoid(self, suma):
        return 1/(1+math.exp(-suma))

    def sf_hyperbolic_tangent(self, suma):
        return (math.exp(suma) - math.exp(-suma)) / (math.exp(suma) + math.exp(-suma))

    def sf_relu(self, suma):
        return max(0, suma)

# %% [markdown]
# ---
# ## Ejercicio 3

# %% [markdown]
# Utilizando la clase Neurona definida previamente, inicializala de tal forma que permita emular la función lógica AND para 2 inputs. Prueba su correcto funcionamiento:

# %%
n3 = Neurona(2, 1)
n3.step_function(np.array([[1,1]]))
# Out:
# 1

# %% [markdown]
# ---
# ## Ejercicio 4

# %% [markdown]
# Utilizando la clase Neurona, inicializala de tal forma que permita emular la función lógica AND para 5 inputs. Prueba su correcto funcionamiento:

# %%
n4 = Neurona(5, 2)
n4.step_function(np.array([[1,1,1,1,1]]))
# Out:
# 0.9589207809428891

# %% [markdown]
# ---
# ## Ejercicio 5

# %% [markdown]
# Utilizando la clase Neurona, inicializala de tal forma que premita emular la función lógica OR para 2 inputs. Prueba su correcto funcionamiento:

# %%
n5 = Neurona(2, 3)
n5.step_function(np.array([[1,1]]))
# Out:
# 0.8302652543478912

# %% [markdown]
# ---
# ## Ejercicio 6

# %% [markdown]
# Utilizando la clase Neurona, inicializala de tal forma que premita emular la función lógica OR para 5 inputs. Prueba su correcto funcionamiento:

# %%
n6 = Neurona(5, 4)
n6.step_function(np.array([[1,1,1,1,1]]))
# Out:
# 3.2666564680009706
